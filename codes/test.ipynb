# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#The old version of library setting
# !pip install pytorch_lightning==1.9.0 torchmetrics==0.7.0 fastmri torch==1.12.0 wandb

# %% [markdown]
# ------------------TRAINING

# %%
#!python /content/drive/MyDrive/Exercise_3/train_VarNet.py --mode train
# Out:
# wandb: Currently logged in as: qiangzhao (qiangzhaoatwandb). Use `wandb login --relogin` to force relogin
# Global seed set to 42
# Size of trainingset: 941
# Size of validationset: 585
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/trainer/connectors/accelerator_connector.py:467: LightningDeprecationWarning: Setting `Trainer(gpus=1)` is deprecated in v1.7 and will be removed in v2.0. Please use `Trainer(accelerator='gpu', devices=1)` instead.
#   rank_zero_deprecation(
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Start training
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name             | Type                 | Params
# ----------------------------------------------------------
# 0 | NMSE             | DistributedMetricSum | 0
# 1 | SSIM             | DistributedMetricSum | 0
# 2 | PSNR             | DistributedMetricSum | 0
# ...

# %%
#AttentionUNet with 10 epochs (deafult)
# !python /content/drive/MyDrive/exercise_3-1/train_VarNet.py --mode train
# Out:
# wandb: Currently logged in as: qiangzhao (qiangzhaoatwandb). Use `wandb login --relogin` to force relogin
# Global seed set to 42
# wandb: Tracking run with wandb version 0.17.0
# wandb: Run data is saved locally in ./wandb/run-20240526_123012-7xp5dpdl
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run Train_VarNet
# wandb: ⭐️ View project at https://wandb.ai/qiangzhaoatwandb/Exercise3
# wandb: 🚀 View run at https://wandb.ai/qiangzhaoatwandb/Exercise3/runs/7xp5dpdl
# Size of trainingset: 941
# Size of validationset: 585
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/trainer/connectors/accelerator_connector.py:467: LightningDeprecationWarning: Setting `Trainer(gpus=1)` is deprecated in v1.7 and will be removed in v2.0. Please use `Trainer(accelerator='gpu', devices=1)` instead.
#   rank_zero_deprecation(
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# ...

# %%
#AttentionUNet with 20 epochs
# !python /content/drive/MyDrive/exercise_3-1/train_VarNet.py --mode train --num_epochs 20 --experiment_name Attention_20epoch
# Out:
# wandb: Currently logged in as: qiangzhao (qiangzhaoatwandb). Use `wandb login --relogin` to force relogin
# Global seed set to 42
# wandb: Tracking run with wandb version 0.17.0
# wandb: Run data is saved locally in ./wandb/run-20240530_232134-i9yjlf8j
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run Attention_20epoch
# wandb: ⭐️ View project at https://wandb.ai/qiangzhaoatwandb/Exercise3
# wandb: 🚀 View run at https://wandb.ai/qiangzhaoatwandb/Exercise3/runs/i9yjlf8j
# Size of trainingset: 941
# Size of validationset: 585
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/trainer/connectors/accelerator_connector.py:467: LightningDeprecationWarning: Setting `Trainer(gpus=1)` is deprecated in v1.7 and will be removed in v2.0. Please use `Trainer(accelerator='gpu', devices=1)` instead.
#   rank_zero_deprecation(
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# ...

# %%
#SparseAttentionUNet with 20 epochs
# !python /content/drive/MyDrive/exercise_3-1/train_VarNet.py --mode train --num_epochs 20 --experiment_name SparseAttention_20epoch

# %%
#UNet with 20 epochs (deafult)
# !python /content/drive/MyDrive/exercise_3-1/train_VarNet.py --mode train --num_epochs 20 --experiment_name Unet_20epoch
# Out:
# wandb: Currently logged in as: qiangzhao (qiangzhaoatwandb). Use `wandb login --relogin` to force relogin
# Global seed set to 42
# wandb: Tracking run with wandb version 0.17.0
# wandb: Run data is saved locally in ./wandb/run-20240530_214507-pkygmal9
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run Unet_20epoch
# wandb: ⭐️ View project at https://wandb.ai/qiangzhaoatwandb/Exercise3
# wandb: 🚀 View run at https://wandb.ai/qiangzhaoatwandb/Exercise3/runs/pkygmal9
# Size of trainingset: 941
# Size of validationset: 585
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/trainer/connectors/accelerator_connector.py:467: LightningDeprecationWarning: Setting `Trainer(gpus=1)` is deprecated in v1.7 and will be removed in v2.0. Please use `Trainer(accelerator='gpu', devices=1)` instead.
#   rank_zero_deprecation(
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# ...

# %% [markdown]
# ------------------TEST

# %%
#Test data-Attention
# !python /content/drive/MyDrive/exercise_3-1/test_VarNet.py --mode test
# Out:
# Global seed set to 42
# Size of trainingset: 1483
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/trainer/connectors/accelerator_connector.py:467: LightningDeprecationWarning: Setting `Trainer(gpus=1)` is deprecated in v1.7 and will be removed in v2.0. Please use `Trainer(accelerator='gpu', devices=1)` instead.
#   rank_zero_deprecation(
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/trainer/connectors/checkpoint_connector.py:55: LightningDeprecationWarning: Setting `Trainer(resume_from_checkpoint=)` is deprecated in v1.5 and will be removed in v2.0. Please pass `Trainer.fit(ckpt_path=)` directly instead.
#   rank_zero_deprecation(
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Restoring states from the checkpoint path at /content/drive/MyDrive/exercise_3-1/varnet/varnet_demo/checkpoints/attention_epoch=19-step=18820-v1.ckpt
# ...

# %%
#Test data-sparse
# !python /content/drive/MyDrive/exercise_3-1/test_VarNet.py --mode test
# Out:
# Global seed set to 42
# Size of trainingset: 1483
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/trainer/connectors/accelerator_connector.py:467: LightningDeprecationWarning: Setting `Trainer(gpus=1)` is deprecated in v1.7 and will be removed in v2.0. Please use `Trainer(accelerator='gpu', devices=1)` instead.
#   rank_zero_deprecation(
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/trainer/connectors/checkpoint_connector.py:55: LightningDeprecationWarning: Setting `Trainer(resume_from_checkpoint=)` is deprecated in v1.5 and will be removed in v2.0. Please pass `Trainer.fit(ckpt_path=)` directly instead.
#   rank_zero_deprecation(
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Restoring states from the checkpoint path at /content/drive/MyDrive/exercise_3-1/varnet/varnet_demo/checkpoints/sparse_attention_epoch=17-step=16938.ckpt
# ...

# %%
#Test data-raw
# !python /content/drive/MyDrive/exercise_3-1/test_VarNet.py --mode test
# Out:
# Global seed set to 42
# Size of trainingset: 1483
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/trainer/connectors/accelerator_connector.py:467: LightningDeprecationWarning: Setting `Trainer(gpus=1)` is deprecated in v1.7 and will be removed in v2.0. Please use `Trainer(accelerator='gpu', devices=1)` instead.
#   rank_zero_deprecation(
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/trainer/connectors/checkpoint_connector.py:55: LightningDeprecationWarning: Setting `Trainer(resume_from_checkpoint=)` is deprecated in v1.5 and will be removed in v2.0. Please pass `Trainer.fit(ckpt_path=)` directly instead.
#   rank_zero_deprecation(
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Restoring states from the checkpoint path at /content/drive/MyDrive/exercise_3-1/varnet/varnet_demo/checkpoints/epoch=18-step=17879-v1.ckpt
# ...
